# %%
import pandas as pd
df = pd.read_csv("dota.csv")
df.head()
# Out:
#     steam_id    match_id  player_slot  kills  deaths  assists  xpm  gpm  \
# 0  118728071  6920406682            4     10       2        8  560  426
# 1  112127522  6920406682            1      8       0        9  684  646
# 2  122334023  6914136246            1     10       5       27  670  370
# 3  106975318  6809430182          132      5       9       17  498  303
# 4  110352369  6864995865          130      4      16        7  628  456
#
#    hero_id  duration  last_hits  lane  lane_role  start_time  hero_damage  \
# 0       26      1929         88     2          2  1671165229        14894
# 1       41      1929        259     1          1  1671165229        15797
# 2        5      2215         31     1          1  1670809762        28118
# 3       30      2785         39     3          1  1665973075        14766
# 4       80      2406        201     3          1  1668487002        11890
#
#    hero_healing  apm  time_spent_dead
# 0             0  164               61
# 1             0  196                0
# 2             0  135              213
# 3          6090  142              370
# 4             0  283              717

# %%
db = df[['steam_id', 'match_id']]
df['steam_id'].dtypes, df['match_id'].dtypes,"\n",db['steam_id'].dtypes, db['match_id'].dtypes
# Out:
# (dtype('int64'), dtype('int64'), '\n', dtype('int64'), dtype('int64'))

# %%
checked_table = df[(df['steam_id'] == 112127522) & (df['match_id'] == 7291683573)]
checked_table
# Out:
#        steam_id    match_id  player_slot  kills  deaths  assists  xpm  gpm  \
# 1245  112127522  7291683573          132      4      16       13  440  361
#
#       hero_id  duration  last_hits  lane  lane_role  start_time  hero_damage  \
# 1245       14      2643        102     1          3  1692418689        17545
#
#       hero_healing  apm  time_spent_dead
# 1245          1444  131              561
